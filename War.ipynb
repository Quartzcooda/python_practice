# %%
from random import shuffle

# %%
dic = {'two':2,'three':3,'four':4,'five':5,'six':6,'seven':7,'eight':8,'nine':9,'ten':10,'jack':11,'queen':12,'king':13,'ace':14}
suite = ('Hearts','Diamonds','Spades','Clubs')
rank = ('Ace','Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King')

# %% [markdown]
# ### Card class

# %%
class Card():
    '''Class for containing individual cards of a deck'''
    def __init__(self,suite,rank):
        self.suite = suite
        self.rank = rank
        self.value = dic[self.rank.lower()]
    
    def __str__(self):
        return f'{self.rank} of {self.suite}'

# %% [markdown]
# ### Deck class

# %%
class Deck():
    '''Class for making decks i.e. a pack of 52 cards'''
    def __init__(self):
        self.all_cards = []
        for n in suite:
            for m in rank:
                self.all_cards.append(Card(n,m))
                
    def shuffle(self):
        '''Function for shuffling a deck'''
        shuffle(self.all_cards)
    
    def pop(self):
        '''Function for dealing cards from a deck'''
        return self.all_cards.pop()

# %% [markdown]
# ### Player class

# %%
class Player():
    '''Class for creating a player'''
    def __init__(self,name,hand):
        self.name = name
        self.hand = hand
        
    def __str__(self):
        return f'Player {self.name} has {len(self.hand)} cards'
    
    def shuffle(self):
        '''Function for shuffling cards in a player's hands'''
        shuffle(self.hand)
    
    def add(self,new_cards):
        '''Function for adding cards to the player's hand'''
        if type(new_cards) == type([]) or type(new_cards) == type(()):
            self.hand.extend(new_cards)
        else:
            self.hand.append(new_cards)
    
    def remove(self):
        '''Function for removing cards from a player's hands'''
        return self.hand.pop(0)

# %% [markdown]
# ### Function for splitting the deck

# %%
def splitting():
    '''Function for creating the players and splitting the deck between them'''
    player1 = input('How should we refer to player 1?\n')
    player2 = input('Player 2 can be called...?\n')
    print('\033[1m'+'The game will now start'+'\033[m')
    d = Deck()
    d.shuffle()
    p1_nc = []
    while len(p1_nc) != 26:
        p1_nc.append(d.pop())
    # Dealing half of the deck to a player
    p2_nc = d.all_cards
    p1 = Player(player1,p1_nc)
    p2 = Player(player2,p2_nc)
    p1.shuffle()
    p2.shuffle()
    return (p1,p2)

# %% [markdown]
# ### Function for doing operation

# %%
def operation(p1,p2):
    '''Function for standoff between the players'''
    card1 = p1.remove()
    card2 = p2.remove()
    print('\033[32;1m'+f'{p1.name} has {card1} and {p2.name} has {card2}'+'\033[m')
    if card1.value > card2.value:
        print('\033[31m'+f'{p1.name} wins this round'+'\033[m')
        p1.add(card1)
        p1.add(card2)
    # If a player wins, both cards go to his hand
        print('\033[34m'+f'{p1} and {p2}'+'\033[m')
    elif card1.value < card2.value:
        print('\033[31m'+f'{p2.name} wins this round'+'\033[m')
        p2.add(card2)
        p2.add(card1)
        print('\033[34m'+f'{p1} and {p2}'+'\033[m')
    else:
        print('\033[31m'+'IT\'S A WAAARRR!!!'+'\033[m')
        p1.add(card1)
        p2.add(card2)
        if len(p1.hand) < 5:
            p1,p2 = drawlesserf(p1,p2)
        elif len(p2.hand) < 5:
            p2,p1 = drawlesserf(p2,p1)
        else:
            p1,p2 = draw(p1,p2)
        # Different cases which can occur when a war happens is covered here
    return (p1,p2)

# %% [markdown]
# ### Function for draw (or war)

# %%
def draw(p1,p2):
    '''Function for executing war'''
    card1,card2 = [],[]
    for n in range(5):
        card1.append(p1.remove())
    for n in range(5):
        card2.append(p2.remove())
    # The first 5 cards of a players hand are removed for the war
    print('\033[32;1m'+f'{p1.name} has {card1[-1]} and {p2.name} has {card2[-1]}'+'\033[m')
    # Only the last card is used in the battle
    if card1[-1].value > card2[-1].value:
        print('\033[31m'+f'{p1.name} wins this round!'+'\033[m')
        p1.add(card1)
        p1.add(card2)
        print('\033[34m'+f'{p1} and {p2}'+'\033[m')
    elif card1[-1].value < card2[-1].value:
        print('\033[31m'+f'{p2.name} wins this round!'+'\033[m')
        p2.add(card2)
        p2.add(card1)
        print('\033[34m'+f'{p1} and {p2}'+'\033[m')
    else:
        print('\033[31m'+'IT\'S A WAAARRR!!!'+'\033[m')
        p1.add(card1)
        p2.add(card2)
        p1,p2 = draw(p1,p2)
    # If a war again occurs, we call the draw function inside itself
    return (p1,p2)

# %% [markdown]
# ### Function for draw when lesser than 5

# %%
def drawlesserf(plf,pgf):
    '''Function for executing war if any one player has less than 5 cards'''
    cardgf,cardlf = [],[]
    for n in range(5):
        cardgf.append(pgf.remove())
    for n in range(len(plf.hand)):
        cardlf.append(plf.remove())
    # For the player who has less than five cards, every card of his is taken into the war
    print('\033[32;1m'+f'{plf.name} has {cardlf[-1]} and {pgf.name} has {cardgf[-1]}'+'\033[m')
    if cardgf[-1].value > cardlf[-1].value:
        print('\033[31m'+f'{pgf.name} wins this round!'+'\033[m')
        pgf.add(cardgf)
        pgf.add(cardlf)
        print('\033[34m'+f'{pgf} and {plf}'+'\033[m')
    elif cardgf[-1].value < cardlf[-1].value:
        print('\033[31m'+f'{plf.name} wins this round!'+'\033[m')
        plf.add(cardlf)
        plf.add(cardgf)
        print('\033[34m'+f'{pgf} and {plf}'+'\033[m')
    else:
        print('\033[31m'+'IT\'S A WAAARRR!!!'+'\033[m')
        pgf.add(cardgf)
        plf.add(cardlf)
        plf,pgf = drawlesserf(p1f,pgf)
    # If there is draw, then the function is called again inside itself as one of the players still has lesser than 5 cards
    return (plf,pgf)

# %% [markdown]
# ### Function for lose condition

# %%
def lose(p1,p2):
    '''Function for lose condition'''
    if len(p1.hand) == 0:
        print('\033[35;1m'+f'{p2.name} has won the game!!!'+'\033[m')
    else:
        print('\033[35;1m'+f'{p1.name} has won the game!!!'+'\033[m')

# %% [markdown]
# ### Main function

# %%
while True:
    start = input('\033[33;1m''Do you want to play a game of War?\nAnswer with yes or no\n''\033[m')
    if start.lower() == 'no':
        break
    elif start.lower() != 'yes':
        print('\033[1m'+'You have not typed a correct input'+'\033[m')
        continue
    # Control flow statements such that game can be started only with the input 'yes'
    p1,p2 = splitting()
    r = 0
    # Variable for counting the number of rounds completed for the game to finish
    while len(p1.hand) != 0 and len(p2.hand) != 0:
    # Loop for repeating the battle until one player has no cards and thus loses
        r += 1
        # Increasing the counter for every round
        p1,p2 = operation(p1,p2)
    lose(p1,p2)
    print('You played a total of {} rounds.'.format(r))
    while True:
        ask = input('Do you want to play again?\nAnswer with yes or no\n')
        if ask.lower() == 'no':
            break
        elif ask.lower() == 'yes':
            break
        else:
            print('Please type yes or no')
            continue
        # Control flow statement for asking to play the game again
    if ask.lower() == 'no':
        break
    continue
# Out:
# Do you want to play a game of War?
# Answer with yes or no
# y
# You have not typed a correct input
# Do you want to play a game of War?
# Answer with yes or no
# yes
# How should we refer to player 1?
# Dora
# Player 2 can be called...?
# Hero
# The game will now start
# Dora has Four of Diamonds and Hero has Four of Clubs
# IT'S A WAAARRR!!!
# Dora has Five of Clubs and Hero has Five of Hearts
# IT'S A WAAARRR!!!
# Dora has Nine of Spades and Hero has Eight of Diamonds
# Dora wins this round!
# Player Dora has 31 cards and Player Hero has 21 cards
# Dora has Jack of Spades and Hero has Queen of Clubs
# Hero wins this round
# Player Dora has 30 cards and Player Hero has 22 cards
# Dora has Jack of Clubs and Hero has Nine of Clubs
# Dora wins this round
# Player Dora has 31 cards and Player Hero has 21 cards
# Dora has Five of Spades and Hero has Jack of Hearts
# Hero wins this round
# Player Dora has 30 cards and Player Hero has 22 cards
# Dora has King of Spades and Hero has Four of Hearts
# Dora wins this round
# Player Dora has 31 cards and Player Hero has 21 cards
# Dora has Three of Spades and Hero has Ten of Spades
# Hero wins this round
# Player Dora has 30 cards and Player Hero has 22 cards
# Dora has Seven of Clubs and Hero has Queen of Hearts
# Hero wins this round
# Player Dora has 29 cards and Player Hero has 23 cards
# Dora has Queen of Spades and Hero has King of Hearts
# Hero wins this round
# Player Dora has 28 cards and Player Hero has 24 cards
# Dora has Seven of Spades and Hero has Ace of Diamonds
# Hero wins this round
# Player Dora has 27 cards and Player Hero has 25 cards
# Dora has Eight of Hearts and Hero has Four of Spades
# Dora wins this round
# Player Dora has 28 cards and Player Hero has 24 cards
# Dora has Two of Clubs and Hero has Three of Hearts
# Hero wins this round
# Player Dora has 27 cards and Player Hero has 25 cards
# Dora has Six of Spades and Hero has Six of Diamonds
# IT'S A WAAARRR!!!
# Dora has Four of Diamonds and Hero has Four of Clubs
# IT'S A WAAARRR!!!
# Dora has Five of Clubs and Hero has Five of Hearts
# IT'S A WAAARRR!!!
# Dora has Nine of Spades and Hero has Ten of Spades
# Hero wins this round!
# Player Dora has 22 cards and Player Hero has 30 cards
# Dora has Three of Diamonds and Hero has Three of Spades
# IT'S A WAAARRR!!!
# Dora has Jack of Clubs and Hero has Ace of Diamonds
# Hero wins this round!
# Player Dora has 17 cards and Player Hero has 35 cards
# Dora has Nine of Clubs and Hero has Seven of Spades
# Dora wins this round
# Player Dora has 18 cards and Player Hero has 34 cards
# Dora has King of Spades and Hero has Three of Hearts
# Dora wins this round
# Player Dora has 19 cards and Player Hero has 33 cards
# Dora has Four of Hearts and Hero has Two of Clubs
# Dora wins this round
# Player Dora has 20 cards and Player Hero has 32 cards
# Dora has Eight of Hearts and Hero has Six of Diamonds
# Dora wins this round
# Player Dora has 21 cards and Player Hero has 31 cards
# Dora has Four of Spades and Hero has Six of Hearts
# Hero wins this round
# Player Dora has 20 cards and Player Hero has 32 cards
# Dora has Six of Spades and Hero has Seven of Diamonds
# Hero wins this round
# Player Dora has 19 cards and Player Hero has 33 cards
# Dora has Ten of Clubs and Hero has Ace of Spades
# Hero wins this round
# Player Dora has 18 cards and Player Hero has 34 cards
# Dora has Six of Clubs and Hero has Two of Spades
# Dora wins this round
# Player Dora has 19 cards and Player Hero has 33 cards
# Dora has Ace of Hearts and Hero has Four of Clubs
# Dora wins this round
# Player Dora has 20 cards and Player Hero has 32 cards
# Dora has Nine of Hearts and Hero has Eight of Spades
# Dora wins this round
# Player Dora has 21 cards and Player Hero has 31 cards
# Dora has Four of Diamonds and Hero has King of Diamonds
# Hero wins this round
# Player Dora has 20 cards and Player Hero has 32 cards
# Dora has Two of Diamonds and Hero has King of Clubs
# Hero wins this round
# Player Dora has 19 cards and Player Hero has 33 cards
# Dora has Ten of Diamonds and Hero has Queen of Diamonds
# Hero wins this round
# Player Dora has 18 cards and Player Hero has 34 cards
# Dora has Three of Clubs and Hero has Five of Hearts
# Hero wins this round
# Player Dora has 17 cards and Player Hero has 35 cards
# Dora has Eight of Clubs and Hero has Queen of Clubs
# Hero wins this round
# Player Dora has 16 cards and Player Hero has 36 cards
# Dora has Five of Clubs and Hero has Jack of Spades
# Hero wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has Three of Diamonds and Hero has Jack of Hearts
# Hero wins this round
# Player Dora has 14 cards and Player Hero has 38 cards
# Dora has Nine of Clubs and Hero has Five of Spades
# Dora wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has Seven of Spades and Hero has Ten of Spades
# Hero wins this round
# Player Dora has 14 cards and Player Hero has 38 cards
# Dora has King of Spades and Hero has Five of Diamonds
# Dora wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has Three of Hearts and Hero has Seven of Hearts
# Hero wins this round
# Player Dora has 14 cards and Player Hero has 38 cards
# Dora has Four of Hearts and Hero has Nine of Diamonds
# Hero wins this round
# Player Dora has 13 cards and Player Hero has 39 cards
# Dora has Two of Clubs and Hero has Ace of Clubs
# Hero wins this round
# Player Dora has 12 cards and Player Hero has 40 cards
# Dora has Eight of Hearts and Hero has Nine of Spades
# Hero wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Six of Diamonds and Hero has Three of Spades
# Dora wins this round
# Player Dora has 12 cards and Player Hero has 40 cards
# Dora has Six of Clubs and Hero has Queen of Hearts
# Hero wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Two of Spades and Hero has Seven of Clubs
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Ace of Hearts and Hero has King of Hearts
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Four of Clubs and Hero has Queen of Spades
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Nine of Hearts and Hero has Ace of Diamonds
# Hero wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Eight of Spades and Hero has Two of Hearts
# Dora wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Nine of Clubs and Hero has Jack of Diamonds
# Hero wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Five of Spades and Hero has Ten of Hearts
# Hero wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has King of Spades and Hero has Eight of Diamonds
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Five of Diamonds and Hero has Jack of Clubs
# Hero wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Six of Diamonds and Hero has Six of Hearts
# IT'S A WAAARRR!!!
# Dora has Two of Hearts and Hero has Ten of Clubs
# Hero wins this round!
# Player Dora has 3 cards and Player Hero has 49 cards
# Dora has King of Spades and Hero has King of Diamonds
# IT'S A WAAARRR!!!
# Dora has King of Spades and Hero has Ten of Diamonds
# Dora wins this round!
# Player Hero has 44 cards and Player Dora has 8 cards
# Dora has Eight of Diamonds and Hero has Five of Hearts
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Six of Diamonds and Hero has Three of Clubs
# Dora wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has King of Spades and Hero has Queen of Clubs
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Four of Diamonds and Hero has Eight of Clubs
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has King of Clubs and Hero has Jack of Spades
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Two of Diamonds and Hero has Five of Clubs
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Queen of Diamonds and Hero has Jack of Hearts
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Ten of Diamonds and Hero has Three of Diamonds
# Dora wins this round
# Player Dora has 12 cards and Player Hero has 40 cards
# Dora has Eight of Diamonds and Hero has Ten of Spades
# Hero wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Five of Hearts and Hero has Seven of Spades
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Six of Diamonds and Hero has Seven of Hearts
# Hero wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Three of Clubs and Hero has Three of Hearts
# IT'S A WAAARRR!!!
# Dora has Queen of Diamonds and Hero has Nine of Spades
# Dora wins this round!
# Player Dora has 14 cards and Player Hero has 38 cards
# Dora has Jack of Hearts and Hero has Eight of Hearts
# Dora wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has Ten of Diamonds and Hero has Queen of Hearts
# Hero wins this round
# Player Dora has 14 cards and Player Hero has 38 cards
# Dora has Three of Diamonds and Hero has Six of Clubs
# Hero wins this round
# Player Dora has 13 cards and Player Hero has 39 cards
# Dora has Three of Clubs and Hero has Seven of Clubs
# Hero wins this round
# Player Dora has 12 cards and Player Hero has 40 cards
# Dora has King of Spades and Hero has Two of Spades
# Dora wins this round
# Player Dora has 13 cards and Player Hero has 39 cards
# Dora has Queen of Clubs and Hero has Queen of Spades
# IT'S A WAAARRR!!!
# Dora has Four of Hearts and Hero has Nine of Clubs
# Hero wins this round!
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Ace of Clubs and Hero has Ten of Hearts
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Two of Clubs and Hero has Five of Spades
# Hero wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Nine of Spades and Hero has Jack of Clubs
# Hero wins this round
# Player Dora has 7 cards and Player Hero has 45 cards
# Dora has Jack of Hearts and Hero has Five of Diamonds
# Dora wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Eight of Hearts and Hero has Six of Hearts
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has King of Spades and Hero has Four of Spades
# Dora wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Two of Spades and Hero has Seven of Diamonds
# Hero wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Queen of Clubs and Hero has Six of Spades
# Dora wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Ace of Clubs and Hero has Ace of Spades
# IT'S A WAAARRR!!!
# Dora has Six of Hearts and Hero has Eight of Spades
# Hero wins this round!
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has King of Spades and Hero has Two of Hearts
# Dora wins this round
# Player Dora has 6 cards and Player Hero has 46 cards
# Dora has Four of Spades and Hero has King of Diamonds
# Hero wins this round
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Queen of Clubs and Hero has Eight of Clubs
# Dora wins this round
# Player Dora has 6 cards and Player Hero has 46 cards
# Dora has Six of Spades and Hero has Four of Diamonds
# Dora wins this round
# Player Dora has 7 cards and Player Hero has 45 cards
# Dora has Ace of Clubs and Hero has Five of Clubs
# Dora wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has King of Spades and Hero has Two of Diamonds
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Two of Hearts and Hero has Ten of Spades
# Hero wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Queen of Clubs and Hero has Eight of Diamonds
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Eight of Clubs and Hero has Seven of Spades
# Dora wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Six of Spades and Hero has Five of Hearts
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Four of Diamonds and Hero has Seven of Hearts
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Ace of Clubs and Hero has Six of Diamonds
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Five of Clubs and Hero has Three of Hearts
# Dora wins this round
# Player Dora has 12 cards and Player Hero has 40 cards
# Dora has King of Spades and Hero has Queen of Hearts
# Dora wins this round
# Player Dora has 13 cards and Player Hero has 39 cards
# Dora has Two of Diamonds and Hero has Ten of Diamonds
# Hero wins this round
# Player Dora has 12 cards and Player Hero has 40 cards
# Dora has Queen of Clubs and Hero has Six of Clubs
# Dora wins this round
# Player Dora has 13 cards and Player Hero has 39 cards
# Dora has Eight of Diamonds and Hero has Three of Diamonds
# Dora wins this round
# Player Dora has 14 cards and Player Hero has 38 cards
# Dora has Eight of Clubs and Hero has Seven of Clubs
# Dora wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has Seven of Spades and Hero has Three of Clubs
# Dora wins this round
# Player Dora has 16 cards and Player Hero has 36 cards
# Dora has Six of Spades and Hero has Queen of Spades
# Hero wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has Five of Hearts and Hero has Four of Clubs
# Dora wins this round
# Player Dora has 16 cards and Player Hero has 36 cards
# Dora has Ace of Clubs and Hero has Ace of Diamonds
# IT'S A WAAARRR!!!
# Dora has Queen of Hearts and Hero has Jack of Spades
# Dora wins this round!
# Player Dora has 21 cards and Player Hero has 31 cards
# Dora has Queen of Clubs and Hero has Queen of Diamonds
# IT'S A WAAARRR!!!
# Dora has Seven of Clubs and Hero has Jack of Clubs
# Hero wins this round!
# Player Dora has 16 cards and Player Hero has 36 cards
# Dora has Seven of Spades and Hero has Nine of Spades
# Hero wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has Three of Clubs and Hero has Seven of Diamonds
# Hero wins this round
# Player Dora has 14 cards and Player Hero has 38 cards
# Dora has Five of Hearts and Hero has Two of Spades
# Dora wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has Four of Clubs and Hero has Ace of Spades
# Hero wins this round
# Player Dora has 14 cards and Player Hero has 38 cards
# Dora has Ace of Clubs and Hero has Ten of Clubs
# Dora wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has Six of Diamonds and Hero has Three of Spades
# Dora wins this round
# Player Dora has 16 cards and Player Hero has 36 cards
# Dora has Five of Clubs and Hero has Ace of Hearts
# Hero wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has Three of Hearts and Hero has King of Hearts
# Hero wins this round
# Player Dora has 14 cards and Player Hero has 38 cards
# Dora has King of Spades and Hero has Eight of Spades
# Dora wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has Queen of Hearts and Hero has Ten of Hearts
# Dora wins this round
# Player Dora has 16 cards and Player Hero has 36 cards
# Dora has Nine of Hearts and Hero has Jack of Hearts
# Hero wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has Jack of Diamonds and Hero has Five of Diamonds
# Dora wins this round
# Player Dora has 16 cards and Player Hero has 36 cards
# Dora has Nine of Clubs and Hero has Eight of Hearts
# Dora wins this round
# Player Dora has 17 cards and Player Hero has 35 cards
# Dora has King of Clubs and Hero has Six of Hearts
# Dora wins this round
# Player Dora has 18 cards and Player Hero has 34 cards
# Dora has Jack of Spades and Hero has King of Diamonds
# Hero wins this round
# Player Dora has 17 cards and Player Hero has 35 cards
# Dora has Queen of Clubs and Hero has Four of Spades
# Dora wins this round
# Player Dora has 18 cards and Player Hero has 34 cards
# Dora has Five of Hearts and Hero has Ten of Spades
# Hero wins this round
# Player Dora has 17 cards and Player Hero has 35 cards
# Dora has Two of Spades and Hero has Two of Hearts
# IT'S A WAAARRR!!!
# Dora has King of Spades and Hero has Queen of Spades
# Dora wins this round!
# Player Dora has 22 cards and Player Hero has 30 cards
# Dora has Eight of Spades and Hero has Six of Spades
# Dora wins this round
# Player Dora has 23 cards and Player Hero has 29 cards
# Dora has Queen of Hearts and Hero has Ace of Diamonds
# Hero wins this round
# Player Dora has 22 cards and Player Hero has 30 cards
# Dora has Ten of Hearts and Hero has Queen of Diamonds
# Hero wins this round
# Player Dora has 21 cards and Player Hero has 31 cards
# Dora has Jack of Diamonds and Hero has Nine of Diamonds
# Dora wins this round
# Player Dora has 22 cards and Player Hero has 30 cards
# Dora has Five of Diamonds and Hero has Four of Hearts
# Dora wins this round
# Player Dora has 23 cards and Player Hero has 29 cards
# Dora has Nine of Clubs and Hero has Five of Spades
# Dora wins this round
# Player Dora has 24 cards and Player Hero has 28 cards
# Dora has Eight of Hearts and Hero has Two of Clubs
# Dora wins this round
# Player Dora has 25 cards and Player Hero has 27 cards
# Dora has King of Clubs and Hero has Jack of Clubs
# Dora wins this round
# Player Dora has 26 cards and Player Hero has 26 cards
# Dora has Six of Hearts and Hero has Six of Clubs
# IT'S A WAAARRR!!!
# Dora has Ten of Clubs and Hero has Nine of Spades
# Dora wins this round!
# Player Dora has 31 cards and Player Hero has 21 cards
# Dora has Six of Diamonds and Hero has Seven of Spades
# Hero wins this round
# Player Dora has 30 cards and Player Hero has 22 cards
# Dora has Three of Spades and Hero has Seven of Diamonds
# Hero wins this round
# Player Dora has 29 cards and Player Hero has 23 cards
# Dora has King of Spades and Hero has Three of Clubs
# Dora wins this round
# Player Dora has 30 cards and Player Hero has 22 cards
# Dora has Seven of Hearts and Hero has Ace of Spades
# Hero wins this round
# Player Dora has 29 cards and Player Hero has 23 cards
# Dora has Four of Diamonds and Hero has Four of Clubs
# IT'S A WAAARRR!!!
# Dora has Six of Spades and Hero has Jack of Hearts
# Hero wins this round!
# Player Dora has 24 cards and Player Hero has 28 cards
# Dora has Jack of Diamonds and Hero has Nine of Hearts
# Dora wins this round
# Player Dora has 25 cards and Player Hero has 27 cards
# Dora has Nine of Diamonds and Hero has King of Diamonds
# Hero wins this round
# Player Dora has 24 cards and Player Hero has 28 cards
# Dora has Five of Diamonds and Hero has Jack of Spades
# Hero wins this round
# Player Dora has 23 cards and Player Hero has 29 cards
# Dora has Four of Hearts and Hero has Ten of Spades
# Hero wins this round
# Player Dora has 22 cards and Player Hero has 30 cards
# Dora has Nine of Clubs and Hero has Five of Hearts
# Dora wins this round
# Player Dora has 23 cards and Player Hero has 29 cards
# Dora has Five of Spades and Hero has Two of Hearts
# Dora wins this round
# Player Dora has 24 cards and Player Hero has 28 cards
# Dora has Eight of Hearts and Hero has Ace of Diamonds
# Hero wins this round
# Player Dora has 23 cards and Player Hero has 29 cards
# Dora has Two of Clubs and Hero has Queen of Hearts
# Hero wins this round
# Player Dora has 22 cards and Player Hero has 30 cards
# Dora has King of Clubs and Hero has Queen of Diamonds
# Dora wins this round
# Player Dora has 23 cards and Player Hero has 29 cards
# Dora has Jack of Clubs and Hero has Ten of Hearts
# Dora wins this round
# Player Dora has 24 cards and Player Hero has 28 cards
# Dora has Six of Hearts and Hero has Six of Clubs
# IT'S A WAAARRR!!!
# Dora has Ten of Clubs and Hero has Ace of Spades
# Hero wins this round!
# Player Dora has 19 cards and Player Hero has 33 cards
# Dora has Eight of Diamonds and Hero has Seven of Hearts
# Dora wins this round
# Player Dora has 20 cards and Player Hero has 32 cards
# Dora has Three of Diamonds and Hero has Four of Clubs
# Hero wins this round
# Player Dora has 19 cards and Player Hero has 33 cards
# Dora has Eight of Clubs and Hero has Ace of Hearts
# Hero wins this round
# Player Dora has 18 cards and Player Hero has 34 cards
# Dora has Seven of Clubs and Hero has Five of Clubs
# Dora wins this round
# Player Dora has 19 cards and Player Hero has 33 cards
# Dora has Nine of Spades and Hero has King of Hearts
# Hero wins this round
# Player Dora has 18 cards and Player Hero has 34 cards
# Dora has King of Spades and Hero has Three of Hearts
# Dora wins this round
# Player Dora has 19 cards and Player Hero has 33 cards
# Dora has Three of Clubs and Hero has Jack of Hearts
# Hero wins this round
# Player Dora has 18 cards and Player Hero has 34 cards
# Dora has Four of Diamonds and Hero has Ten of Diamonds
# Hero wins this round
# Player Dora has 17 cards and Player Hero has 35 cards
# Dora has Jack of Diamonds and Hero has Two of Diamonds
# Dora wins this round
# Player Dora has 18 cards and Player Hero has 34 cards
# Dora has Nine of Hearts and Hero has Queen of Spades
# Hero wins this round
# Player Dora has 17 cards and Player Hero has 35 cards
# Dora has Nine of Clubs and Hero has Eight of Spades
# Dora wins this round
# Player Dora has 18 cards and Player Hero has 34 cards
# Dora has Five of Hearts and Hero has Six of Spades
# Hero wins this round
# Player Dora has 17 cards and Player Hero has 35 cards
# Dora has Five of Spades and Hero has King of Diamonds
# Hero wins this round
# Player Dora has 16 cards and Player Hero has 36 cards
# Dora has Two of Hearts and Hero has Nine of Diamonds
# Hero wins this round
# Player Dora has 15 cards and Player Hero has 37 cards
# Dora has King of Clubs and Hero has Jack of Spades
# Dora wins this round
# Player Dora has 16 cards and Player Hero has 36 cards
# Dora has Queen of Diamonds and Hero has Five of Diamonds
# Dora wins this round
# Player Dora has 17 cards and Player Hero has 35 cards
# Dora has Jack of Clubs and Hero has Ten of Spades
# Dora wins this round
# Player Dora has 18 cards and Player Hero has 34 cards
# Dora has Ten of Hearts and Hero has Four of Hearts
# Dora wins this round
# Player Dora has 19 cards and Player Hero has 33 cards
# Dora has Six of Hearts and Hero has Ace of Diamonds
# Hero wins this round
# Player Dora has 18 cards and Player Hero has 34 cards
# Dora has Eight of Diamonds and Hero has Eight of Hearts
# IT'S A WAAARRR!!!
# Dora has Three of Hearts and Hero has Six of Diamonds
# Hero wins this round!
# Player Dora has 13 cards and Player Hero has 39 cards
# Dora has Jack of Diamonds and Hero has Seven of Diamonds
# Dora wins this round
# Player Dora has 14 cards and Player Hero has 38 cards
# Dora has Two of Diamonds and Hero has Three of Spades
# Hero wins this round
# Player Dora has 13 cards and Player Hero has 39 cards
# Dora has Nine of Clubs and Hero has Ace of Spades
# Hero wins this round
# Player Dora has 12 cards and Player Hero has 40 cards
# Dora has Eight of Spades and Hero has Queen of Clubs
# Hero wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has King of Clubs and Hero has Four of Spades
# Dora wins this round
# Player Dora has 12 cards and Player Hero has 40 cards
# Dora has Jack of Spades and Hero has Two of Spades
# Dora wins this round
# Player Dora has 13 cards and Player Hero has 39 cards
# Dora has Queen of Diamonds and Hero has Ace of Clubs
# Hero wins this round
# Player Dora has 12 cards and Player Hero has 40 cards
# Dora has Five of Diamonds and Hero has Ten of Clubs
# Hero wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Jack of Clubs and Hero has Four of Clubs
# Dora wins this round
# Player Dora has 12 cards and Player Hero has 40 cards
# Dora has Ten of Spades and Hero has Three of Diamonds
# Dora wins this round
# Player Dora has 13 cards and Player Hero has 39 cards
# Dora has Ten of Hearts and Hero has Ace of Hearts
# Hero wins this round
# Player Dora has 12 cards and Player Hero has 40 cards
# Dora has Four of Hearts and Hero has Eight of Clubs
# Hero wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Eight of Diamonds and Hero has King of Hearts
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Jack of Diamonds and Hero has Nine of Spades
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Seven of Diamonds and Hero has Jack of Hearts
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has King of Clubs and Hero has Three of Clubs
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Four of Spades and Hero has Ten of Diamonds
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Jack of Spades and Hero has Four of Diamonds
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Two of Spades and Hero has Queen of Spades
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Jack of Clubs and Hero has Nine of Hearts
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Four of Clubs and Hero has Six of Spades
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Ten of Spades and Hero has Five of Hearts
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Three of Diamonds and Hero has King of Diamonds
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Jack of Diamonds and Hero has Five of Spades
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Nine of Spades and Hero has Nine of Diamonds
# IT'S A WAAARRR!!!
# Dora has Jack of Clubs and Hero has Queen of Hearts
# Hero wins this round!
# Player Dora has 6 cards and Player Hero has 46 cards
# Dora has Nine of Hearts and Hero has Two of Clubs
# Dora wins this round
# Player Dora has 7 cards and Player Hero has 45 cards
# Dora has Ten of Spades and Hero has Six of Clubs
# Dora wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Five of Hearts and Hero has Seven of Spades
# Hero wins this round
# Player Dora has 7 cards and Player Hero has 45 cards
# Dora has Jack of Diamonds and Hero has Six of Diamonds
# Dora wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Five of Spades and Hero has Seven of Hearts
# Hero wins this round
# Player Dora has 7 cards and Player Hero has 45 cards
# Dora has Nine of Spades and Hero has Seven of Clubs
# Dora wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Nine of Hearts and Hero has Five of Clubs
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Two of Clubs and Hero has King of Spades
# Hero wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Ten of Spades and Hero has Three of Hearts
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Six of Clubs and Hero has Three of Spades
# Dora wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Jack of Diamonds and Hero has Two of Diamonds
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Six of Diamonds and Hero has Ace of Spades
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Nine of Spades and Hero has Nine of Clubs
# IT'S A WAAARRR!!!
# Dora has Three of Hearts and Hero has Ten of Clubs
# Hero wins this round!
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Six of Clubs and Hero has Five of Diamonds
# Dora wins this round
# Player Dora has 6 cards and Player Hero has 46 cards
# Dora has Three of Spades and Hero has Ace of Hearts
# Hero wins this round
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Jack of Diamonds and Hero has Ten of Hearts
# Dora wins this round
# Player Dora has 6 cards and Player Hero has 46 cards
# Dora has Two of Diamonds and Hero has Eight of Clubs
# Hero wins this round
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Nine of Spades and Hero has Four of Hearts
# Dora wins this round
# Player Dora has 6 cards and Player Hero has 46 cards
# Dora has Six of Clubs and Hero has King of Hearts
# Hero wins this round
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Five of Diamonds and Hero has Eight of Diamonds
# Hero wins this round
# Player Dora has 4 cards and Player Hero has 48 cards
# Dora has Jack of Diamonds and Hero has Jack of Hearts
# IT'S A WAAARRR!!!
# Dora has Jack of Diamonds and Hero has Two of Spades
# Dora wins this round!
# Player Hero has 43 cards and Player Dora has 9 cards
# Dora has Ten of Hearts and Hero has Six of Spades
# Dora wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Nine of Spades and Hero has Four of Clubs
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Four of Hearts and Hero has King of Diamonds
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Jack of Diamonds and Hero has Three of Diamonds
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Seven of Diamonds and Hero has Nine of Diamonds
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Ten of Diamonds and Hero has Two of Hearts
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Four of Spades and Hero has Ace of Diamonds
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Queen of Spades and Hero has Six of Hearts
# Dora wins this round
# Player Dora has 11 cards and Player Hero has 41 cards
# Dora has Two of Spades and Hero has Eight of Hearts
# Hero wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Ten of Hearts and Hero has Queen of Hearts
# Hero wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Six of Spades and Hero has King of Clubs
# Hero wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Nine of Spades and Hero has Three of Clubs
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Four of Clubs and Hero has Jack of Spades
# Hero wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Jack of Diamonds and Hero has Four of Diamonds
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Three of Diamonds and Hero has Jack of Clubs
# Hero wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Ten of Diamonds and Hero has Seven of Spades
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Two of Hearts and Hero has Five of Hearts
# Hero wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Queen of Spades and Hero has Seven of Hearts
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Six of Hearts and Hero has Five of Spades
# Dora wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Nine of Spades and Hero has King of Spades
# Hero wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Three of Clubs and Hero has Two of Clubs
# Dora wins this round
# Player Dora has 10 cards and Player Hero has 42 cards
# Dora has Jack of Diamonds and Hero has Ace of Spades
# Hero wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Four of Diamonds and Hero has Six of Diamonds
# Hero wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Ten of Diamonds and Hero has Nine of Clubs
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Seven of Spades and Hero has Queen of Clubs
# Hero wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Queen of Spades and Hero has Eight of Spades
# Dora wins this round
# Player Dora has 9 cards and Player Hero has 43 cards
# Dora has Seven of Hearts and Hero has Ace of Clubs
# Hero wins this round
# Player Dora has 8 cards and Player Hero has 44 cards
# Dora has Six of Hearts and Hero has Queen of Diamonds
# Hero wins this round
# Player Dora has 7 cards and Player Hero has 45 cards
# Dora has Five of Spades and Hero has Ten of Clubs
# Hero wins this round
# Player Dora has 6 cards and Player Hero has 46 cards
# Dora has Three of Clubs and Hero has Seven of Clubs
# Hero wins this round
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Two of Clubs and Hero has Nine of Hearts
# Hero wins this round
# Player Dora has 4 cards and Player Hero has 48 cards
# Dora has Ten of Diamonds and Hero has Five of Clubs
# Dora wins this round
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Nine of Clubs and Hero has Ten of Spades
# Hero wins this round
# Player Dora has 4 cards and Player Hero has 48 cards
# Dora has Queen of Spades and Hero has Three of Hearts
# Dora wins this round
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Eight of Spades and Hero has Ace of Hearts
# Hero wins this round
# Player Dora has 4 cards and Player Hero has 48 cards
# Dora has Ten of Diamonds and Hero has Three of Spades
# Dora wins this round
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Five of Clubs and Hero has Eight of Clubs
# Hero wins this round
# Player Dora has 4 cards and Player Hero has 48 cards
# Dora has Queen of Spades and Hero has Two of Diamonds
# Dora wins this round
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Three of Hearts and Hero has King of Hearts
# Hero wins this round
# Player Dora has 4 cards and Player Hero has 48 cards
# Dora has Ten of Diamonds and Hero has Six of Clubs
# Dora wins this round
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Three of Spades and Hero has Eight of Diamonds
# Hero wins this round
# Player Dora has 4 cards and Player Hero has 48 cards
# Dora has Queen of Spades and Hero has Five of Diamonds
# Dora wins this round
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Two of Diamonds and Hero has Jack of Hearts
# Hero wins this round
# Player Dora has 4 cards and Player Hero has 48 cards
# Dora has Ten of Diamonds and Hero has King of Diamonds
# Hero wins this round
# Player Dora has 3 cards and Player Hero has 49 cards
# Dora has Six of Clubs and Hero has Four of Hearts
# Dora wins this round
# Player Dora has 4 cards and Player Hero has 48 cards
# Dora has Queen of Spades and Hero has Nine of Diamonds
# Dora wins this round
# Player Dora has 5 cards and Player Hero has 47 cards
# Dora has Five of Diamonds and Hero has Seven of Diamonds
# Hero wins this round
# Player Dora has 4 cards and Player Hero has 48 cards
# Dora has Six of Clubs and Hero has Ace of Diamonds
# Hero wins this round
# Player Dora has 3 cards and Player Hero has 49 cards
# Dora has Four of Hearts and Hero has Four of Spades
# IT'S A WAAARRR!!!
# Dora has Four of Hearts and Hero has King of Clubs
# Hero wins this round!
# Player Hero has 52 cards and Player Dora has 0 cards
# Hero has won the game!!!
# You played a total of 258 rounds.
# Do you want to play again?
# y
# Please type yes or no
# Do you want to play again?
# yes
# Do you want to play a game of War?
# Answer with yes or no
# no
